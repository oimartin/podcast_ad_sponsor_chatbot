# %% [markdown]
# # Import Dependencies

# %%
import nltk
import random
import numpy as np

# !pip install sentence_transformers
from sentence_transformers import SentenceTransformer

from elasticsearch import Elasticsearch

# Assuming you have already created an Elasticsearch client instance 'es'
es = Elasticsearch("http://localhost:9200")
import pandas as pd

import torch
import torch.nn.functional as F

import time
import nltk

from typing import Tuple


from transformers import AutoTokenizer, AutoModel
pre_trained_model_name = "sebastian-hofstaetter/distilbert-dot-tas_b-b256-msmarco"

tokenizer = AutoTokenizer.from_pretrained(pre_trained_model_name) 
bert_model = AutoModel.from_pretrained(pre_trained_model_name)

# %% [markdown]
# # Test sebastian-hofstaetter/distilbert-dot-tas_b-b256-msmarco on Episodes

# %%
# test sebastian-hofstaetter/distilbert-dot-tas_b-b256-msmarco on indicator episodes
indicator_episodes = ["spotify:episode:5fG4VlWnWwzAt6mSs0H7lY", "spotify:episode:7JG3lLnRoDdOxuqjf14ZkM",
                            "spotify:episode:3kkhUQJ9DXYs6aSdDmPp2V", "spotify:episode:4fJ6Y6IpljKy8FT8DZHx1L",
                            "spotify:episode:5xBPWxqVCocdBgybmHjr5V", "spotify:episode:0X663c1I6j1cehJvy10WMm", 
                            "spotify:episode:61a1JjZO27lGCvCwBaCkpC", "spotify:episode:0goWRy1gwB23rQVy8ci7Wa", 
                            "spotify:episode:0BSD8QYmd2mQ1V43uIrU4I", "spotify:episode:5xH3cdpkxnJhQjPV22sxKC",
                            "spotify:episode:0YPvJfSEw0jacPB3IeT37d", "spotify:episode:1gnpv26FFvIxpnwVbbRXv1",
                            "spotify:episode:6rh4J52THn252yi7t11Yqf", "spotify:episode:3IfmcM2rcWb82601pkPvCh",
                            "spotify:episode:5LJ33LdXWhqOu1KNad6D5q", "spotify:episode:1AxFBio6NwwG0MAjdCK5gK",
                            "spotify:episode:3U33mRnDJcXywmBm1hahlL", "spotify:episode:57Nzb9H2VRZgHcNFChwbBG",
                            "spotify:episode:6vRLNVEQ4xqtMxnms3RZh3", "spotify:episode:1tN044BhlPjjiluZ7Wo7UL",
                            "spotify:episode:1fs86N6FLUKW2e5NdX1dF1", "spotify:episode:1A4cHtP3wIVQutpCgS7kd7",
                            "spotify:episode:1Mi90UjG91rm73qvHzcG0t", "spotify:episode:3TuC8HZp9VdXtxYMQkJI0m",
                            "spotify:episode:67v8V9SOXxivYQfAHSsc5f", "spotify:episode:3QE8qxHtJg3zMrq03R4GOj",
                            "spotify:episode:3Vr6AUCTQgVWoE137b4IdB", "spotify:episode:4oQZAcd6xnxVA1e2GWaIFb",
                            "spotify:episode:4sbSs1xtuf8dF3xtb7btUi", "spotify:episode:2RoLspr2PQTki51sfMhd20"]

# %%
def apply_distilbert_dot_model(sentence:str,error_list:list):-> Tuple:

""" 
    Applies the distilbert dot model to the sentence and returns the sentence and the score for the sentence.

    Args:
        sentence (str): The sentence to be evaluated.
        error_list (list): The list of sentences that were not evaluated.

    Returns:
        Tuple: The sentence and the score for the sentence.
"""

    error_sentences = []
    try:
        # Encode the sentence
        sentence_input = tokenizer(sentence, return_tensors="pt")
    except Exception as error:
        print("Error:", error)
        print("Something wrong with the sentence tokenization", sentence)
        error_list.append(sentence)
        pass
    
    try:
        # Confert ids to tokens 
        tokenizer.convert_ids_to_tokens(sentence_input["input_ids"][0])
    except Exception as error:
        print("Error:", error)
        print("Something wrong with the sentence tokenization, converting ids to tokens", sentence)
        error_list.append(sentence)
        pass

    try:
        # Encode the query
        passage1_encoded = bert_model(**sentence_input)[0][:,0,:].squeeze(0)
    except Exception as error:
        print("Error:", error)
        print("Something wrong with the sentence encoding", sentence)
        error_list.append(sentence)
        pass

    try:
        # Produce dot score for passage
        score_for_p1 = query_encoded.dot(passage1_encoded)
    except Exception as error:
        print("Error:", error)
        print("Something wrong with the sentence encoding", sentence)
        error_list.append(sentence)
        pass
    return sentence, score_for_p1

# %%
of_interest = []

# Query input
query_input = tokenizer("who are the advertisers, sponsors, advertisement, or ads and/or businesses, people, teams thanked?",return_tensors="pt")
print("Query Tokenized:",tokenizer.convert_ids_to_tokens(query_input["input_ids"][0]))
query_encoded    = bert_model(**query_input)[0][:,0,:].squeeze(0)

# Loop through all the episodes
for episode in indicator_episodes:
    
    try:
        episode_ = {
            "query": {
                "match_phrase": {
                    "_id": episode,
                }
            }
        }

        # Execute the Elasticsearch search query
        # show_search_results = es.search(index="spotify_podcast_transcripts", body=show_body)
        results = es.search(index="spotify_podcast_transcripts", body=episode_)

        # Extract relevant information from the search results
        hits = results["hits"]["hits"]
    except Exception as error:
        print("Error:", error)
        print("Something wrong with retrieving the episode from Elasticsearch")

    start = time.time()
    print("start epsiode:", episode)
    
    try:
        # Loop through all the sentences in the episode
        sentence_score = []
        error_sentences = []

        # Split the sentences into parts if they are too long
        for sentence in hits[0]['_source']['sentence_tokens']:
            sentence_len = len(sentence)

            # If the sentence is longer than 800 tokens, split it into parts
            if sentence_len > 800:
                split_by = 2
                split = round(sentence_len // split_by,0)
                
                # Split the sentence into parts
                sentence_split = [sentence[i:i+split] for i in range(0, len(sentence), split)]
                print("splitting sentence of length:", sentence_len, "into", split_by, "parts of length:", split)

                # Loop through all the parts
                for sentence in sentence_split:

                    # Apply the distillbert_dot_model
                    sentence, score_for_p1 = apply_distilbert_dot_model(sentence, error_sentences)
                    sentence_score.append((sentence, score_for_p1.item()))
        
            # If the sentence is shorter than 800 tokens, apply the distillbert_dot model without sectioning
            sentence, score_for_p1 = apply_distilbert_dot_model(sentence, error_sentences)
            sentence_score.append((sentence, score_for_p1.item()))

            end = time.time()
    except Exception as error:
        print("Error:", error)
        print("Something wrong with the sentence scoring", sentence)
    
    # Sort the sentences by their score
    sentence_score.sort(key=lambda tup: tup[1], reverse=True)

    # take the top 30 responses and scores
    top_responses = [sentence[0] for sentence in sentence_score[:30]]
    top25_scores = [sentence[1] for sentence in sentence_score[:30]]
    
    # print("top 25 responses:", top_responses)
    # print("top 25 scores:", top25_scores)

    total_time = round((end-start)/60, 2)
    print(f"Total time for {episode}: {total_time} minutes")

    episode_info = pd.DataFrame({
        "episode_uri": episode,
        "top_responses": top_responses,
        "top_scores": top25_scores,
        "total_time": total_time
        })
    print(episode_info.shape)
    of_interest.append(episode_info)

print(len(of_interest))
# Out:
# Query Tokenized: ['[CLS]', 'who', 'are', 'the', 'ad', '##vert', '##iser', '##s', ',', 'sponsors', ',', 'advertisement', ',', 'or', 'ads', 'and', '/', 'or', 'businesses', ',', 'people', ',', 'teams', 'thanked', '?', '[SEP]']
# start epsiode: spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# splitting sentence of length: 1194 into 2 parts of length: 597
# splitting sentence of length: 1144 into 2 parts of length: 572
# splitting sentence of length: 3463 into 2 parts of length: 1731
# splitting sentence of length: 1037 into 2 parts of length: 518
# splitting sentence of length: 1290 into 2 parts of length: 645
# splitting sentence of length: 1183 into 2 parts of length: 591
# splitting sentence of length: 4175 into 2 parts of length: 2087
# splitting sentence of length: 1502 into 2 parts of length: 751
# Total time for spotify:episode:5fG4VlWnWwzAt6mSs0H7lY: 0.89 minutes
# (30, 4)
# start epsiode: spotify:episode:7JG3lLnRoDdOxuqjf14ZkM
# Total time for spotify:episode:7JG3lLnRoDdOxuqjf14ZkM: 0.56 minutes
# (30, 4)
# start epsiode: spotify:episode:3kkhUQJ9DXYs6aSdDmPp2V
# splitting sentence of length: 895 into 2 parts of length: 447
# splitting sentence of length: 2487 into 2 parts of length: 1243
# splitting sentence of length: 2848 into 2 parts of length: 1424
# Total time for spotify:episode:3kkhUQJ9DXYs6aSdDmPp2V: 0.63 minutes
# (30, 4)
# start epsiode: spotify:episode:4fJ6Y6IpljKy8FT8DZHx1L
# splitting sentence of length: 955 into 2 parts of length: 477
# Total time for spotify:episode:4fJ6Y6IpljKy8FT8DZHx1L: 0.57 minutes
# (30, 4)
# start epsiode: spotify:episode:5xBPWxqVCocdBgybmHjr5V
# splitting sentence of length: 825 into 2 parts of length: 412
# splitting sentence of length: 1145 into 2 parts of length: 572
# splitting sentence of length: 1769 into 2 parts of length: 884
# splitting sentence of length: 2125 into 2 parts of length: 1062
# splitting sentence of length: 933 into 2 parts of length: 466
# splitting sentence of length: 2089 into 2 parts of length: 1044
# splitting sentence of length: 1323 into 2 parts of length: 661
# Total time for spotify:episode:5xBPWxqVCocdBgybmHjr5V: 0.78 minutes
# (30, 4)
# start epsiode: spotify:episode:0X663c1I6j1cehJvy10WMm
# Total time for spotify:episode:0X663c1I6j1cehJvy10WMm: 0.29 minutes
# (30, 4)
# start epsiode: spotify:episode:61a1JjZO27lGCvCwBaCkpC
# Total time for spotify:episode:61a1JjZO27lGCvCwBaCkpC: 0.65 minutes
# (30, 4)
# start epsiode: spotify:episode:0goWRy1gwB23rQVy8ci7Wa
# splitting sentence of length: 884 into 2 parts of length: 442
# splitting sentence of length: 885 into 2 parts of length: 442
# splitting sentence of length: 984 into 2 parts of length: 492
# splitting sentence of length: 836 into 2 parts of length: 418
# Total time for spotify:episode:0goWRy1gwB23rQVy8ci7Wa: 0.61 minutes
# (30, 4)
# start epsiode: spotify:episode:0BSD8QYmd2mQ1V43uIrU4I
# Total time for spotify:episode:0BSD8QYmd2mQ1V43uIrU4I: 0.3 minutes
# (30, 4)
# start epsiode: spotify:episode:5xH3cdpkxnJhQjPV22sxKC
# Total time for spotify:episode:5xH3cdpkxnJhQjPV22sxKC: 0.15 minutes
# (30, 4)
# start epsiode: spotify:episode:0YPvJfSEw0jacPB3IeT37d
# Total time for spotify:episode:0YPvJfSEw0jacPB3IeT37d: 0.4 minutes
# (30, 4)
# start epsiode: spotify:episode:1gnpv26FFvIxpnwVbbRXv1
# Total time for spotify:episode:1gnpv26FFvIxpnwVbbRXv1: 0.08 minutes
# (30, 4)
# start epsiode: spotify:episode:6rh4J52THn252yi7t11Yqf
# Total time for spotify:episode:6rh4J52THn252yi7t11Yqf: 0.42 minutes
# (30, 4)
# start epsiode: spotify:episode:3IfmcM2rcWb82601pkPvCh
# splitting sentence of length: 803 into 2 parts of length: 401
# Total time for spotify:episode:3IfmcM2rcWb82601pkPvCh: 0.1 minutes
# (30, 4)
# start epsiode: spotify:episode:5LJ33LdXWhqOu1KNad6D5q
# Total time for spotify:episode:5LJ33LdXWhqOu1KNad6D5q: 0.09 minutes
# (30, 4)
# start epsiode: spotify:episode:1AxFBio6NwwG0MAjdCK5gK
# Total time for spotify:episode:1AxFBio6NwwG0MAjdCK5gK: 0.18 minutes
# (30, 4)
# start epsiode: spotify:episode:3U33mRnDJcXywmBm1hahlL
# splitting sentence of length: 830 into 2 parts of length: 415
# splitting sentence of length: 2526 into 2 parts of length: 1263
# splitting sentence of length: 5921 into 2 parts of length: 2960
# Error: index out of range in self
# Something wrong with the sentence encoding so that she didn't because she did like they did go and do things but like they don't know that they know that she came in like this dude this dude a thing and I read out the problem instead she's about to get murdered I'm all out of beer I'm so lost without you I can't believe we're still reading this thing we're not we're almost done anyway to executioner step forward they press the tips of their wants and Newton Cena's neck Tina is so overcome with shock and fear she can barely speak Graves like do it immediately  Lee I will inform president pichkiri myself newts like Tina but Graves places a finger on his lips and says which I guess is supposed to be I don't know it doesn't matter who's in me please please please  oh God there's no NV p no there really is it honestly like I'm not flying with I don't suppose she'll like no this is the thing I read this I was having I was hanging out with the four-legged crew and I was reading this and so it was like distracted reading this like let me reread this before we start recording so I could at least try to figure it out and I didn't that didn't happen but  there was no MVP then there's no the P now there's no BP mmm well you know shout out to Jim a Chan and Carmen ejogo forgetting give me them coins despite the mess you know getting those coins out to them but like I don't know that makes you MVP but also like imagine being in a Harry Potter for dozens of the residuals aren't hitting know I know they're not they're not I mean it's on like can you watch this on it feels good maybe even still like they're in like just watching it who's watching it but also like they're not in that much so but Carmen ejogo got  her light I mean she has to get paid for funko's right like when they're not really her like this yeah  face is on the thing  she got merchandising right no okay I don't you know I have no idea  so Bianca have known BP W every piece herself for cutting the games giving the team the money to just do the thing and watch the movies we would have ended up here anyway we're not using that money from that Maggie MVP son named British Envoy / Minister for Tech staying on top of criminal element and causing International incidents true he was very well informed true  that's not on that cool bench time in stomach ooza  for being super  incompetent and like and I usually read somebody about letting Grindelwald go in the biggest standing right next to you y'all hang up the fog waterfall of truth whatever you're like ours like what the dude and the thing that's hilarious is that  polish is pushing is taught and fourth year third year no it's a new level okay yeah so she just put you can read about it in a second here well no she went to the extremes Restricted Section and you can yeah she scammed her ways to get okay but Polyjuice Potion to the thing that exists in this world yeah and it's maybe not as nearly as much to combat against this yeah it's a maybe it's not as
# Error: local variable 'passage1_encoded' referenced before assignment
# Something wrong with the sentence encoding so that she didn't because she did like they did go and do things but like they don't know that they know that she came in like this dude this dude a thing and I read out the problem instead she's about to get murdered I'm all out of beer I'm so lost without you I can't believe we're still reading this thing we're not we're almost done anyway to executioner step forward they press the tips of their wants and Newton Cena's neck Tina is so overcome with shock and fear she can barely speak Graves like do it immediately  Lee I will inform president pichkiri myself newts like Tina but Graves places a finger on his lips and says which I guess is supposed to be I don't know it doesn't matter who's in me please please please  oh God there's no NV p no there really is it honestly like I'm not flying with I don't suppose she'll like no this is the thing I read this I was having I was hanging out with the four-legged crew and I was reading this and so it was like distracted reading this like let me reread this before we start recording so I could at least try to figure it out and I didn't that didn't happen but  there was no MVP then there's no the P now there's no BP mmm well you know shout out to Jim a Chan and Carmen ejogo forgetting give me them coins despite the mess you know getting those coins out to them but like I don't know that makes you MVP but also like imagine being in a Harry Potter for dozens of the residuals aren't hitting know I know they're not they're not I mean it's on like can you watch this on it feels good maybe even still like they're in like just watching it who's watching it but also like they're not in that much so but Carmen ejogo got  her light I mean she has to get paid for funko's right like when they're not really her like this yeah  face is on the thing  she got merchandising right no okay I don't you know I have no idea  so Bianca have known BP W every piece herself for cutting the games giving the team the money to just do the thing and watch the movies we would have ended up here anyway we're not using that money from that Maggie MVP son named British Envoy / Minister for Tech staying on top of criminal element and causing International incidents true he was very well informed true  that's not on that cool bench time in stomach ooza  for being super  incompetent and like and I usually read somebody about letting Grindelwald go in the biggest standing right next to you y'all hang up the fog waterfall of truth whatever you're like ours like what the dude and the thing that's hilarious is that  polish is pushing is taught and fourth year third year no it's a new level okay yeah so she just put you can read about it in a second here well no she went to the extremes Restricted Section and you can yeah she scammed her ways to get okay but Polyjuice Potion to the thing that exists in this world yeah and it's maybe not as nearly as much to combat against this yeah it's a maybe it's not as
# Error: local variable 'score_for_p1' referenced before assignment
# Something wrong with the sentence scoring so that she didn't because she did like they did go and do things but like they don't know that they know that she came in like this dude this dude a thing and I read out the problem instead she's about to get murdered I'm all out of beer I'm so lost without you I can't believe we're still reading this thing we're not we're almost done anyway to executioner step forward they press the tips of their wants and Newton Cena's neck Tina is so overcome with shock and fear she can barely speak Graves like do it immediately  Lee I will inform president pichkiri myself newts like Tina but Graves places a finger on his lips and says which I guess is supposed to be I don't know it doesn't matter who's in me please please please  oh God there's no NV p no there really is it honestly like I'm not flying with I don't suppose she'll like no this is the thing I read this I was having I was hanging out with the four-legged crew and I was reading this and so it was like distracted reading this like let me reread this before we start recording so I could at least try to figure it out and I didn't that didn't happen but  there was no MVP then there's no the P now there's no BP mmm well you know shout out to Jim a Chan and Carmen ejogo forgetting give me them coins despite the mess you know getting those coins out to them but like I don't know that makes you MVP but also like imagine being in a Harry Potter for dozens of the residuals aren't hitting know I know they're not they're not I mean it's on like can you watch this on it feels good maybe even still like they're in like just watching it who's watching it but also like they're not in that much so but Carmen ejogo got  her light I mean she has to get paid for funko's right like when they're not really her like this yeah  face is on the thing  she got merchandising right no okay I don't you know I have no idea  so Bianca have known BP W every piece herself for cutting the games giving the team the money to just do the thing and watch the movies we would have ended up here anyway we're not using that money from that Maggie MVP son named British Envoy / Minister for Tech staying on top of criminal element and causing International incidents true he was very well informed true  that's not on that cool bench time in stomach ooza  for being super  incompetent and like and I usually read somebody about letting Grindelwald go in the biggest standing right next to you y'all hang up the fog waterfall of truth whatever you're like ours like what the dude and the thing that's hilarious is that  polish is pushing is taught and fourth year third year no it's a new level okay yeah so she just put you can read about it in a second here well no she went to the extremes Restricted Section and you can yeah she scammed her ways to get okay but Polyjuice Potion to the thing that exists in this world yeah and it's maybe not as nearly as much to combat against this yeah it's a maybe it's not as
# Total time for spotify:episode:3U33mRnDJcXywmBm1hahlL: 0.74 minutes
# (30, 4)
# start epsiode: spotify:episode:57Nzb9H2VRZgHcNFChwbBG
# Total time for spotify:episode:57Nzb9H2VRZgHcNFChwbBG: 0.13 minutes
# (30, 4)
# start epsiode: spotify:episode:6vRLNVEQ4xqtMxnms3RZh3
# Total time for spotify:episode:6vRLNVEQ4xqtMxnms3RZh3: 0.29 minutes
# (30, 4)
# start epsiode: spotify:episode:1tN044BhlPjjiluZ7Wo7UL
# splitting sentence of length: 884 into 2 parts of length: 442
# Total time for spotify:episode:1tN044BhlPjjiluZ7Wo7UL: 0.14 minutes
# (30, 4)
# start epsiode: spotify:episode:1fs86N6FLUKW2e5NdX1dF1
# splitting sentence of length: 810 into 2 parts of length: 405
# Total time for spotify:episode:1fs86N6FLUKW2e5NdX1dF1: 0.43 minutes
# (30, 4)
# start epsiode: spotify:episode:1A4cHtP3wIVQutpCgS7kd7
# splitting sentence of length: 1185 into 2 parts of length: 592
# Total time for spotify:episode:1A4cHtP3wIVQutpCgS7kd7: 0.76 minutes
# (30, 4)
# start epsiode: spotify:episode:1Mi90UjG91rm73qvHzcG0t
# Total time for spotify:episode:1Mi90UjG91rm73qvHzcG0t: 0.02 minutes
# (18, 4)
# start epsiode: spotify:episode:3TuC8HZp9VdXtxYMQkJI0m
# Total time for spotify:episode:3TuC8HZp9VdXtxYMQkJI0m: 0.1 minutes
# (30, 4)
# start epsiode: spotify:episode:67v8V9SOXxivYQfAHSsc5f
# Total time for spotify:episode:67v8V9SOXxivYQfAHSsc5f: 0.16 minutes
# (30, 4)
# start epsiode: spotify:episode:3QE8qxHtJg3zMrq03R4GOj
# Total time for spotify:episode:3QE8qxHtJg3zMrq03R4GOj: 0.57 minutes
# (30, 4)
# start epsiode: spotify:episode:3Vr6AUCTQgVWoE137b4IdB
# Total time for spotify:episode:3Vr6AUCTQgVWoE137b4IdB: 0.49 minutes
# (30, 4)
# start epsiode: spotify:episode:4oQZAcd6xnxVA1e2GWaIFb
# Total time for spotify:episode:4oQZAcd6xnxVA1e2GWaIFb: 0.2 minutes
# (30, 4)
# start epsiode: spotify:episode:4sbSs1xtuf8dF3xtb7btUi
# Total time for spotify:episode:4sbSs1xtuf8dF3xtb7btUi: 0.41 minutes
# (30, 4)
# start epsiode: spotify:episode:2RoLspr2PQTki51sfMhd20
# Total time for spotify:episode:2RoLspr2PQTki51sfMhd20: 0.29 minutes
# (30, 4)
# 30

# %%
error_sentences
# Out:
# []

# %%
of_interest[0]
# Out:
#                                episode_uri  \
# 0   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 1   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 2   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 3   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 4   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 5   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 6   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 7   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 8   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 9   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 10  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 11  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 12  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 13  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 14  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 15  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 16  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 17  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 18  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 19  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 20  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 21  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 22  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 23  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 24  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 25  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 26  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 27  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 28  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 29  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
#
#                                         top_responses  top_scores  total_time
# 0   Oh, yeah other Shooters we're super fortunate ...   89.197632        0.89
# 1   I can't I can't but but like I'm just that's w...   89.057426        0.89
# 2   And I don't know there's a lot of people inter...   88.724937        0.89
# 3   It's always a great experience in like you're ...   88.405342        0.89
# 4   It's just so funny shown up because there's so...   88.268860        0.89
# 5   I think like in teams remaining that's or people.   88.256111        0.89
# 6   An organized team and get fucking thrash and t...   88.139984        0.89
# 7   So we're all kind of like, I'm not helping any...   88.095894        0.89
# 8   So everyone's like playing as an individual as...   87.896950        0.89
# 9   And you're all the right spots, but you just g...   87.706169        0.89
# 10  They were God's squads that proved themselves ...   87.381538        0.89
# 11  or like different players that are coming up i...   87.260712        0.89
# 12  They're right and still like trying to sign pl...   87.169685        0.89
# 13  I couldnt game like think of like people can b...   86.946877        0.89
# 14  Like there's just not I mean like there's alwa...   86.882935        0.89
# 15  Like we were there's like a short list of peop...   86.840881        0.89
# 16  But that just honestly meant there were more t...   86.824142        0.89
# 17  Because again, it was always like what the fuc...   86.807281        0.89
# 18  Yeah, we've been we've been thinking about doi...   86.694450        0.89
# 19                                    I'm sorry guys.   86.675606        0.89
# 20                                   What's up, guys?   86.593498        0.89
# 21  I want to go on we're talking about like stupi...   86.497482        0.89
# 22  And so we were Justin and I weren't even on th...   86.460419        0.89
# 23  We were talking about people that we were worr...   86.445976        0.89
# 24  They're like bro, and then you're thinking tha...   86.358261        0.89
# 25  I feel like I feel like a really important par...   86.313103        0.89
# 26  They're saying like every pro team at the top ...   86.299591        0.89
# 27  I think like yeah, we rocked with like the old...   86.292343        0.89
# 28  Like I just meaning that was there you guys it...   86.250954        0.89
# 29  And yeah, we're going to try to you know, how ...   86.228424        0.89

# %%
# of_interest[0]
# Out:
#                                episode_uri  \
# 0   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 1   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 2   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 3   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 4   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 5   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 6   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 7   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 8   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 9   spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 10  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 11  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 12  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 13  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 14  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 15  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 16  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 17  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 18  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 19  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 20  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 21  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 22  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 23  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 24  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 25  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 26  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 27  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 28  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 29  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
#
#                                         top_responses  top_scores  total_time
# 0   Oh, yeah other Shooters we're super fortunate ...   89.197632        0.93
# 1   I can't I can't but but like I'm just that's w...   89.057426        0.93
# 2   And I don't know there's a lot of people inter...   88.724937        0.93
# 3   It's always a great experience in like you're ...   88.405342        0.93
# 4   It's just so funny shown up because there's so...   88.268860        0.93
# 5   I think like in teams remaining that's or people.   88.256111        0.93
# 6   An organized team and get fucking thrash and t...   88.139984        0.93
# 7   So we're all kind of like, I'm not helping any...   88.095894        0.93
# 8   So everyone's like playing as an individual as...   87.896950        0.93
# 9   And you're all the right spots, but you just g...   87.706169        0.93
# 10  If Call of Duty teams like Chicago Huntsman an...   87.445641        0.93
# 11  They were God's squads that proved themselves ...   87.381538        0.93
# 12  ial incentive for companies to run events for ...   87.363647        0.93
# 13  They're right and still like trying to sign pl...   87.169685        0.93
# 14  I couldnt game like think of like people can b...   86.946877        0.93
# 15  in his tweet actually he said it pretty well I...   86.933517        0.93
# 16  in his tweet actually he said it pretty well I...   86.933517        0.93
# 17  Like there's just not I mean like there's alwa...   86.882935        0.93
# 18  Like we were there's like a short list of peop...   86.840881        0.93
# 19  But that just honestly meant there were more t...   86.824142        0.93
# 20  Because again, it was always like what the fuc...   86.807281        0.93
# 21  t so it's like there's a lot of incentive ther...   86.759514        0.93
# 22  Yeah, we've been we've been thinking about doi...   86.694450        0.93
# 23                                    I'm sorry guys.   86.675606        0.93
# 24                                   What's up, guys?   86.593498        0.93
# 25  I want to go on we're talking about like stupi...   86.497482        0.93
# 26  And so we were Justin and I weren't even on th...   86.460419        0.93
# 27  We were talking about people that we were worr...   86.445976        0.93
# 28  They're like bro, and then you're thinking tha...   86.358261        0.93
# 29  I feel like I feel like a really important par...   86.313103        0.93

# %%
for df in of_interest:
    display(df.head())
# Out:
#                               episode_uri  \
# 0  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 1  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 2  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 3  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 4  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
#
#                                        top_responses  top_scores  total_time
# 0  Oh, yeah other Shooters we're super fortunate ...   89.197632        0.89
# 1  I can't I can't but but like I'm just that's w...   89.057426        0.89
# 2  And I don't know there's a lot of people inter...   88.724937        0.89
# 3  It's always a great experience in like you're ...   88.405342        0.89
# 4  It's just so funny shown up because there's so...   88.268860        0.89
#                               episode_uri  \
# 0  spotify:episode:7JG3lLnRoDdOxuqjf14ZkM
# 1  spotify:episode:7JG3lLnRoDdOxuqjf14ZkM
# 2  spotify:episode:7JG3lLnRoDdOxuqjf14ZkM
# 3  spotify:episode:7JG3lLnRoDdOxuqjf14ZkM
# 4  spotify:episode:7JG3lLnRoDdOxuqjf14ZkM
#
#                                        top_responses  top_scores  total_time
# 0  I mean, those are you know, there's some signi...   88.281265        0.56
# 1  I thought that's this was they had something g...   87.972641        0.56
# 2  So well, I mean like we're going on informatio...   87.631943        0.56
# 3  But I also know that fans like Kyra Williams b...   86.817825        0.56
# 4                        We think we know who it is.   86.626434        0.56
#                               episode_uri  \
# 0  spotify:episode:3kkhUQJ9DXYs6aSdDmPp2V
# 1  spotify:episode:3kkhUQJ9DXYs6aSdDmPp2V
# 2  spotify:episode:3kkhUQJ9DXYs6aSdDmPp2V
# 3  spotify:episode:3kkhUQJ9DXYs6aSdDmPp2V
# 4  spotify:episode:3kkhUQJ9DXYs6aSdDmPp2V
#
#                                        top_responses  top_scores  total_time
# 0  ed about, you know, like what it is to be like...   89.186562        0.63
# 1  and sometimes they're halfway across the count...   89.177628        0.63
# 2  And a lot of the women's groups on Facebook an...   88.689362        0.63
# 3  Ronnie when wherever we're up that way, but ye...   88.287003        0.63
# 4  You know, I run a website you've got  And peop...   87.610291        0.63
#                               episode_uri  \
# 0  spotify:episode:4fJ6Y6IpljKy8FT8DZHx1L
# 1  spotify:episode:4fJ6Y6IpljKy8FT8DZHx1L
# 2  spotify:episode:4fJ6Y6IpljKy8FT8DZHx1L
# 3  spotify:episode:4fJ6Y6IpljKy8FT8DZHx1L
# 4  spotify:episode:4fJ6Y6IpljKy8FT8DZHx1L
#
#                                        top_responses  top_scores  total_time
# 0  So, you know, that's that's one reason why we ...   92.369278        0.57
# 1  We're doing giveaways announcements things lik...   89.140060        0.57
# 2  You know Heroes on the water, you know, it def...   88.581161        0.57
# 3                    We're joined columns and right.   88.402306        0.57
# 4                                 Thank you so much.   88.307861        0.57
#                               episode_uri  \
# 0  spotify:episode:5xBPWxqVCocdBgybmHjr5V
# 1  spotify:episode:5xBPWxqVCocdBgybmHjr5V
# 2  spotify:episode:5xBPWxqVCocdBgybmHjr5V
# 3  spotify:episode:5xBPWxqVCocdBgybmHjr5V
# 4  spotify:episode:5xBPWxqVCocdBgybmHjr5V
#
#                                        top_responses  top_scores  total_time
# 0  So you got any anybody like to thank sponsor s...   91.726151        0.78
# 1                              I had some customers.   89.408089        0.78
# 2              Well, thanks a lot of guys like that.   89.261078        0.78
# 3          All right you guys to thanks a lot again.   89.106979        0.78
# 4                                            Thanks.   89.094635        0.78
#                               episode_uri  \
# 0  spotify:episode:0X663c1I6j1cehJvy10WMm
# 1  spotify:episode:0X663c1I6j1cehJvy10WMm
# 2  spotify:episode:0X663c1I6j1cehJvy10WMm
# 3  spotify:episode:0X663c1I6j1cehJvy10WMm
# 4  spotify:episode:0X663c1I6j1cehJvy10WMm
#
#                                        top_responses  top_scores  total_time
# 0  We are all in this together everything from bu...   89.035439        0.29
# 1  So I'm happy to say that I have enough faith i...   88.109879        0.29
# 2  Just went all over the faces of the people sit...   87.690369        0.29
# 3                   Thank you so much for listening.   87.602249        0.29
# 4  I want to talk about the impacts that are happ...   87.313004        0.29
#                               episode_uri  \
# 0  spotify:episode:61a1JjZO27lGCvCwBaCkpC
# 1  spotify:episode:61a1JjZO27lGCvCwBaCkpC
# 2  spotify:episode:61a1JjZO27lGCvCwBaCkpC
# 3  spotify:episode:61a1JjZO27lGCvCwBaCkpC
# 4  spotify:episode:61a1JjZO27lGCvCwBaCkpC
#
#                                        top_responses  top_scores  total_time
# 0                                         Thank you.   89.589943        0.65
# 1                                            Thanks.   89.094635        0.65
# 2  We're just so blessed and happy that you came ...   89.013054        0.65
# 3  We're so excited and you guys know where to fi...   88.213264        0.65
# 4  Behavior when presented with the same prompt t...   87.904770        0.65
#                               episode_uri  \
# 0  spotify:episode:0goWRy1gwB23rQVy8ci7Wa
# 1  spotify:episode:0goWRy1gwB23rQVy8ci7Wa
# 2  spotify:episode:0goWRy1gwB23rQVy8ci7Wa
# 3  spotify:episode:0goWRy1gwB23rQVy8ci7Wa
# 4  spotify:episode:0goWRy1gwB23rQVy8ci7Wa
#
#                                        top_responses  top_scores  total_time
# 0  Good job, but also we gave I put up a post on ...   87.776657        0.61
# 1  Questions to tackle, but before we start specu...   87.741821        0.61
# 2                     So thank you very much to you.   87.721283        0.61
# 3     It's a great I think message for anyone right?   87.452133        0.61
# 4  We have they've got they've given us officiall...   86.986946        0.61
#                               episode_uri  \
# 0  spotify:episode:0BSD8QYmd2mQ1V43uIrU4I
# 1  spotify:episode:0BSD8QYmd2mQ1V43uIrU4I
# 2  spotify:episode:0BSD8QYmd2mQ1V43uIrU4I
# 3  spotify:episode:0BSD8QYmd2mQ1V43uIrU4I
# 4  spotify:episode:0BSD8QYmd2mQ1V43uIrU4I
#
#                                        top_responses  top_scores  total_time
# 0  Ruminating on what mistakes the Christian demo...   86.351860         0.3
# 1  It was the red brigades each caller conveyed t...   86.301300         0.3
# 2  Accusation to make but that was it to everyone...   86.255318         0.3
# 3  Aldo was candid about the failings of the Chri...   86.128883         0.3
# 4  While these futile efforts continued a debate ...   86.128006         0.3
#                               episode_uri  \
# 0  spotify:episode:5xH3cdpkxnJhQjPV22sxKC
# 1  spotify:episode:5xH3cdpkxnJhQjPV22sxKC
# 2  spotify:episode:5xH3cdpkxnJhQjPV22sxKC
# 3  spotify:episode:5xH3cdpkxnJhQjPV22sxKC
# 4  spotify:episode:5xH3cdpkxnJhQjPV22sxKC
#
#                                        top_responses  top_scores  total_time
# 0  There are too many different motives only thre...   85.812935        0.15
# 1  Our next assassin had a more selfish reasoning...   85.683319        0.15
# 2  He said only four percent of victims receive d...   85.526329        0.15
# 3  It was a question fool and family echoed the i...   85.372192        0.15
# 4  Officially Booth wanted revenge on the man who...   85.049820        0.15
#                               episode_uri  \
# 0  spotify:episode:0YPvJfSEw0jacPB3IeT37d
# 1  spotify:episode:0YPvJfSEw0jacPB3IeT37d
# 2  spotify:episode:0YPvJfSEw0jacPB3IeT37d
# 3  spotify:episode:0YPvJfSEw0jacPB3IeT37d
# 4  spotify:episode:0YPvJfSEw0jacPB3IeT37d
#
#                                        top_responses  top_scores  total_time
# 0  So I highlighted a large section here, but I r...   87.531731         0.4
# 1  But if you're a person of color and have a lot...   87.215431         0.4
# 2  But first of all, we'll go through and do our ...   87.074615         0.4
# 3  You know, the one where they've got the main e...   86.967964         0.4
# 4  Thank you so much for joining us Anna you guys...   86.402550         0.4
#                               episode_uri  \
# 0  spotify:episode:1gnpv26FFvIxpnwVbbRXv1
# 1  spotify:episode:1gnpv26FFvIxpnwVbbRXv1
# 2  spotify:episode:1gnpv26FFvIxpnwVbbRXv1
# 3  spotify:episode:1gnpv26FFvIxpnwVbbRXv1
# 4  spotify:episode:1gnpv26FFvIxpnwVbbRXv1
#
#                                        top_responses  top_scores  total_time
# 0  If you have a message if you have some come co...   85.782341        0.08
# 1  I had my name balls did my practices I have re...   85.033485        0.08
# 2  Now my Skyrim everyone welcome back to my shoe...   84.972702        0.08
# 3  It's lot and I hope this possibilities availab...   84.891136        0.08
# 4  I want myself back sir, but accessible to you ...   84.821716        0.08
#                               episode_uri  \
# 0  spotify:episode:6rh4J52THn252yi7t11Yqf
# 1  spotify:episode:6rh4J52THn252yi7t11Yqf
# 2  spotify:episode:6rh4J52THn252yi7t11Yqf
# 3  spotify:episode:6rh4J52THn252yi7t11Yqf
# 4  spotify:episode:6rh4J52THn252yi7t11Yqf
#
#                                        top_responses  top_scores  total_time
# 0            I really apologize you and I thank you.   88.978973        0.42
# 1                                     I applaud you.   88.309372        0.42
# 2  Just please listen, he's helping me and it mak...   87.807602        0.42
# 3  I never dared me and I wish I did but I just n...   87.645622        0.42
# 4  Oh my God, I'm really a good friend and David ...   86.723396        0.42
#                               episode_uri  \
# 0  spotify:episode:3IfmcM2rcWb82601pkPvCh
# 1  spotify:episode:3IfmcM2rcWb82601pkPvCh
# 2  spotify:episode:3IfmcM2rcWb82601pkPvCh
# 3  spotify:episode:3IfmcM2rcWb82601pkPvCh
# 4  spotify:episode:3IfmcM2rcWb82601pkPvCh
#
#                                        top_responses  top_scores  total_time
# 0  Thank you listeners for supporting these incre...   89.696877         0.1
# 1  Today's episode is sponsored by glory and shin...   87.014542         0.1
# 2  Why didn't we see that showing up in love and ...   86.254257         0.1
# 3  She is Beloved the  Driver, yes beloved the ca...   86.108673         0.1
# 4  You can find her on Instagram at Krug The Thin...   86.108315         0.1
#                               episode_uri  \
# 0  spotify:episode:5LJ33LdXWhqOu1KNad6D5q
# 1  spotify:episode:5LJ33LdXWhqOu1KNad6D5q
# 2  spotify:episode:5LJ33LdXWhqOu1KNad6D5q
# 3  spotify:episode:5LJ33LdXWhqOu1KNad6D5q
# 4  spotify:episode:5LJ33LdXWhqOu1KNad6D5q
#
#                                        top_responses  top_scores  total_time
# 0  Thank you listeners for supporting these incre...   89.696877        0.09
# 1  Today's episode is sponsored by glory and shin...   87.014542        0.09
# 2  Today's episode is all  Also sponsored by pray...   85.987732        0.09
# 3  She is passionate about her faith and has cont...   85.194092        0.09
# 4            Please visit pray more Retreat dot-org.   84.700455        0.09
#                               episode_uri  \
# 0  spotify:episode:1AxFBio6NwwG0MAjdCK5gK
# 1  spotify:episode:1AxFBio6NwwG0MAjdCK5gK
# 2  spotify:episode:1AxFBio6NwwG0MAjdCK5gK
# 3  spotify:episode:1AxFBio6NwwG0MAjdCK5gK
# 4  spotify:episode:1AxFBio6NwwG0MAjdCK5gK
#
#                                        top_responses  top_scores  total_time
# 0                                         Thank you.   89.589943        0.18
# 1                                               Etc.   86.950890        0.18
# 2  I've got a question first well means please go...   85.642418        0.18
# 3  Even those trusted crew members can sometimes ...   85.614006        0.18
# 4  Our pilgrimage pod and Facebook at the pilgrim...   85.602974        0.18
#                               episode_uri  \
# 0  spotify:episode:3U33mRnDJcXywmBm1hahlL
# 1  spotify:episode:3U33mRnDJcXywmBm1hahlL
# 2  spotify:episode:3U33mRnDJcXywmBm1hahlL
# 3  spotify:episode:3U33mRnDJcXywmBm1hahlL
# 4  spotify:episode:3U33mRnDJcXywmBm1hahlL
#
#                                        top_responses  top_scores  total_time
# 0                                         Thank you.   89.589943        0.74
# 1                                         Thank you.   89.589943        0.74
# 2  We have some announcements and reminders is an...   88.014763        0.74
# 3  So Tina's like who's been Bianca that making m...   87.644440        0.74
# 4       So, please feel free to tweet along with us.   87.111893        0.74
#                               episode_uri  \
# 0  spotify:episode:57Nzb9H2VRZgHcNFChwbBG
# 1  spotify:episode:57Nzb9H2VRZgHcNFChwbBG
# 2  spotify:episode:57Nzb9H2VRZgHcNFChwbBG
# 3  spotify:episode:57Nzb9H2VRZgHcNFChwbBG
# 4  spotify:episode:57Nzb9H2VRZgHcNFChwbBG
#
#                                        top_responses  top_scores  total_time
# 0  Also, if you want to be if you want to sponsor...   89.189102        0.13
# 1                                         Thank God.   88.359428        0.13
# 2                   Thank you so much for listening.   87.602249        0.13
# 3  Hey, maybe one of those things of this hopeful...   86.950150        0.13
# 4  I'm on a  Mobile hairdressing page and I asked...   86.920303        0.13
#                               episode_uri  \
# 0  spotify:episode:6vRLNVEQ4xqtMxnms3RZh3
# 1  spotify:episode:6vRLNVEQ4xqtMxnms3RZh3
# 2  spotify:episode:6vRLNVEQ4xqtMxnms3RZh3
# 3  spotify:episode:6vRLNVEQ4xqtMxnms3RZh3
# 4  spotify:episode:6vRLNVEQ4xqtMxnms3RZh3
#
#                                        top_responses  top_scores  total_time
# 0  They love it and you know investors are drivin...   88.753769        0.29
# 1  We talked about earlier, but they also offer o...   88.405243        0.29
# 2      You know, I'm somebody who's been doing this.   87.956009        0.29
# 3  There's something called eBay Bucks A lot of p...   87.790627        0.29
# 4  If you want like links to those just DME and I...   87.660431        0.29
#                               episode_uri  \
# 0  spotify:episode:1tN044BhlPjjiluZ7Wo7UL
# 1  spotify:episode:1tN044BhlPjjiluZ7Wo7UL
# 2  spotify:episode:1tN044BhlPjjiluZ7Wo7UL
# 3  spotify:episode:1tN044BhlPjjiluZ7Wo7UL
# 4  spotify:episode:1tN044BhlPjjiluZ7Wo7UL
#
#                                        top_responses  top_scores  total_time
# 0     Thanks so much and we'll see you all tomorrow.   87.432022        0.14
# 1  So now that we've gone over the major points a...   85.319595        0.14
# 2  And most within one hour they did not comment ...   84.946251        0.14
# 3  Keep in mind that this podcast is designed to ...   84.841286        0.14
# 4  This is the ortho bullets podcast a daily audi...   84.583199        0.14
#                               episode_uri  \
# 0  spotify:episode:1fs86N6FLUKW2e5NdX1dF1
# 1  spotify:episode:1fs86N6FLUKW2e5NdX1dF1
# 2  spotify:episode:1fs86N6FLUKW2e5NdX1dF1
# 3  spotify:episode:1fs86N6FLUKW2e5NdX1dF1
# 4  spotify:episode:1fs86N6FLUKW2e5NdX1dF1
#
#                                        top_responses  top_scores  total_time
# 0  I would say like entirely  So I would like to ...   89.339706        0.43
# 1  Their appreciation support for the franchise a...   88.945366        0.43
# 2                    Thank you all for your support.   88.551247        0.43
# 3                          It would be very welcome.   87.483360        0.43
# 4  They're going to be paying attention to number...   87.419342        0.43
#                               episode_uri  \
# 0  spotify:episode:1A4cHtP3wIVQutpCgS7kd7
# 1  spotify:episode:1A4cHtP3wIVQutpCgS7kd7
# 2  spotify:episode:1A4cHtP3wIVQutpCgS7kd7
# 3  spotify:episode:1A4cHtP3wIVQutpCgS7kd7
# 4  spotify:episode:1A4cHtP3wIVQutpCgS7kd7
#
#                                        top_responses  top_scores  total_time
# 0             And that is it guys few announcements.   89.736458        0.76
# 1                          Thank you for joining us.   89.038361        0.76
# 2  Don't forget to like comment and subscribe to ...   87.686356        0.76
# 3  Like like you you hype up these people the ent...   87.495583        0.76
# 4                         Thanks for listening guys.   87.459137        0.76
#                               episode_uri  \
# 0  spotify:episode:1Mi90UjG91rm73qvHzcG0t
# 1  spotify:episode:1Mi90UjG91rm73qvHzcG0t
# 2  spotify:episode:1Mi90UjG91rm73qvHzcG0t
# 3  spotify:episode:1Mi90UjG91rm73qvHzcG0t
# 4  spotify:episode:1Mi90UjG91rm73qvHzcG0t
#
#                                        top_responses  top_scores  total_time
# 0                                       Hi everyone.   86.922188        0.02
# 1  In the near term Asian markets may be in for c...   83.844490        0.02
# 2  This has been a podcast from ocbc Bank follow ...   83.572586        0.02
# 3  I'm Selena Ling Chief Economist for CPC bang t...   83.389191        0.02
# 4  If you reference the G7 meeting of Finance Chi...   83.141045        0.02
#                               episode_uri  \
# 0  spotify:episode:3TuC8HZp9VdXtxYMQkJI0m
# 1  spotify:episode:3TuC8HZp9VdXtxYMQkJI0m
# 2  spotify:episode:3TuC8HZp9VdXtxYMQkJI0m
# 3  spotify:episode:3TuC8HZp9VdXtxYMQkJI0m
# 4  spotify:episode:3TuC8HZp9VdXtxYMQkJI0m
#
#                                        top_responses  top_scores  total_time
# 0                                         Thank you.   89.589943         0.1
# 1                I hope you do to thank you so much.   88.546982         0.1
# 2  He's with mr. D. Hello and welcome to Friday f...   86.276268         0.1
# 3          Thanks for having happy Friday everybody.   85.741425         0.1
# 4  I know they do have a parent or advisory warni...   85.498055         0.1
#                               episode_uri  \
# 0  spotify:episode:67v8V9SOXxivYQfAHSsc5f
# 1  spotify:episode:67v8V9SOXxivYQfAHSsc5f
# 2  spotify:episode:67v8V9SOXxivYQfAHSsc5f
# 3  spotify:episode:67v8V9SOXxivYQfAHSsc5f
# 4  spotify:episode:67v8V9SOXxivYQfAHSsc5f
#
#                                        top_responses  top_scores  total_time
# 0                    Thank you so much for chatting.   88.334587        0.16
# 1  Thank you so much for joining me on for the lo...   87.355186        0.16
# 2                          Thank you so much Rodman.   86.162308        0.16
# 3                         I'm so excited to be here.   85.876465        0.16
# 4  Do you have any tips for teachers I guess to p...   85.684448        0.16
#                               episode_uri  \
# 0  spotify:episode:3QE8qxHtJg3zMrq03R4GOj
# 1  spotify:episode:3QE8qxHtJg3zMrq03R4GOj
# 2  spotify:episode:3QE8qxHtJg3zMrq03R4GOj
# 3  spotify:episode:3QE8qxHtJg3zMrq03R4GOj
# 4  spotify:episode:3QE8qxHtJg3zMrq03R4GOj
#
#                                        top_responses  top_scores  total_time
# 0         We just want to say thanks to our sponsor.   95.078430        0.57
# 1  And today Spotify is one of our sponsors on Sp...   92.813988        0.57
# 2                                         Thank you.   89.589943        0.57
# 3                                         Thank you.   89.589943        0.57
# 4                                         Thank you.   89.589943        0.57
#                               episode_uri  \
# 0  spotify:episode:3Vr6AUCTQgVWoE137b4IdB
# 1  spotify:episode:3Vr6AUCTQgVWoE137b4IdB
# 2  spotify:episode:3Vr6AUCTQgVWoE137b4IdB
# 3  spotify:episode:3Vr6AUCTQgVWoE137b4IdB
# 4  spotify:episode:3Vr6AUCTQgVWoE137b4IdB
#
#                                        top_responses  top_scores  total_time
# 0  So that's and if I'm proud of it, but it's par...   87.354828        0.49
# 1                                            We are.   87.203232        0.49
# 2  But my guess is that people who work with you ...   87.027206        0.49
# 3  I think that you know, I just sort of help peo...   86.817032        0.49
# 4  for example  I can give you one example that c...   86.807785        0.49
#                               episode_uri  \
# 0  spotify:episode:4oQZAcd6xnxVA1e2GWaIFb
# 1  spotify:episode:4oQZAcd6xnxVA1e2GWaIFb
# 2  spotify:episode:4oQZAcd6xnxVA1e2GWaIFb
# 3  spotify:episode:4oQZAcd6xnxVA1e2GWaIFb
# 4  spotify:episode:4oQZAcd6xnxVA1e2GWaIFb
#
#                                        top_responses  top_scores  total_time
# 0                                         Thank you.   89.589943         0.2
# 1                                     But thank God.   88.522011         0.2
# 2             And thanks again for joining us today.   88.509727         0.2
# 3                              Thank you again, man.   88.089447         0.2
# 4  I've used other platforms, and I'm so happy I ...   87.564529         0.2
#                               episode_uri  \
# 0  spotify:episode:4sbSs1xtuf8dF3xtb7btUi
# 1  spotify:episode:4sbSs1xtuf8dF3xtb7btUi
# 2  spotify:episode:4sbSs1xtuf8dF3xtb7btUi
# 3  spotify:episode:4sbSs1xtuf8dF3xtb7btUi
# 4  spotify:episode:4sbSs1xtuf8dF3xtb7btUi
#
#                                        top_responses  top_scores  total_time
# 0  They will even help you find other companies t...   90.060837        0.41
# 1                                  We're your hosts.   89.264397        0.41
# 2  So they're waving and everything and because o...   87.569412        0.41
# 3  We want to take some time to introduce you to ...   87.446594        0.41
# 4  So again, thanks for listening and we'll see y...   86.970871        0.41
#                               episode_uri  \
# 0  spotify:episode:2RoLspr2PQTki51sfMhd20
# 1  spotify:episode:2RoLspr2PQTki51sfMhd20
# 2  spotify:episode:2RoLspr2PQTki51sfMhd20
# 3  spotify:episode:2RoLspr2PQTki51sfMhd20
# 4  spotify:episode:2RoLspr2PQTki51sfMhd20
#
#                                        top_responses  top_scores  total_time
# 0  We are grateful for you our listeners you allo...   90.327499        0.29
# 1  In other words Congressional staffers are  Ed ...   86.872383        0.29
# 2                              Thanks for listening.   86.267189        0.29
# 3  Is or his wife's election campaigns any favors...   86.216476        0.29
# 4  He'd already talked about wanting to work with...   85.902397        0.29

# %%
# for df in of_interest:
#     display(df.head())
# Out:
#                               episode_uri  \
# 0  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 1  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 2  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 3  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 4  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
#
#                                        top_responses  top_scores  total_time
# 0  Oh, yeah other Shooters we're super fortunate ...   89.197632        0.93
# 1  I can't I can't but but like I'm just that's w...   89.057426        0.93
# 2  And I don't know there's a lot of people inter...   88.724937        0.93
# 3  It's always a great experience in like you're ...   88.405342        0.93
# 4  It's just so funny shown up because there's so...   88.268860        0.93
#                               episode_uri  \
# 0  spotify:episode:7JG3lLnRoDdOxuqjf14ZkM
# 1  spotify:episode:7JG3lLnRoDdOxuqjf14ZkM
# 2  spotify:episode:7JG3lLnRoDdOxuqjf14ZkM
# 3  spotify:episode:7JG3lLnRoDdOxuqjf14ZkM
# 4  spotify:episode:7JG3lLnRoDdOxuqjf14ZkM
#
#                                        top_responses  top_scores  total_time
# 0  I mean, those are you know, there's some signi...   88.281265        0.63
# 1  I thought that's this was they had something g...   87.972641        0.63
# 2  So well, I mean like we're going on informatio...   87.631943        0.63
# 3  But I also know that fans like Kyra Williams b...   86.817825        0.63
# 4                        We think we know who it is.   86.626434        0.63
#                               episode_uri  \
# 0  spotify:episode:3kkhUQJ9DXYs6aSdDmPp2V
# 1  spotify:episode:3kkhUQJ9DXYs6aSdDmPp2V
# 2  spotify:episode:3kkhUQJ9DXYs6aSdDmPp2V
# 3  spotify:episode:3kkhUQJ9DXYs6aSdDmPp2V
# 4  spotify:episode:3kkhUQJ9DXYs6aSdDmPp2V
#
#                                        top_responses  top_scores  total_time
# 0  now, so it's trying to get the sponsors as wel...   92.697548        0.69
# 1   about that on KP in the other night to know w...   89.100616        0.69
# 2  And a lot of the women's groups on Facebook an...   88.689362        0.69
# 3  Ronnie when wherever we're up that way, but ye...   88.287003        0.69
# 4  You know, I run a website you've got  And peop...   87.610291        0.69
#                               episode_uri  \
# 0  spotify:episode:4fJ6Y6IpljKy8FT8DZHx1L
# 1  spotify:episode:4fJ6Y6IpljKy8FT8DZHx1L
# 2  spotify:episode:4fJ6Y6IpljKy8FT8DZHx1L
# 3  spotify:episode:4fJ6Y6IpljKy8FT8DZHx1L
# 4  spotify:episode:4fJ6Y6IpljKy8FT8DZHx1L
#
#                                        top_responses  top_scores  total_time
# 0  So, you know, that's that's one reason why we ...   92.369278        0.64
# 1  We're doing giveaways announcements things lik...   89.140060        0.64
# 2  You know Heroes on the water, you know, it def...   88.581161        0.64
# 3                    We're joined columns and right.   88.402306        0.64
# 4                                 Thank you so much.   88.307861        0.64
#                               episode_uri  \
# 0  spotify:episode:5xBPWxqVCocdBgybmHjr5V
# 1  spotify:episode:5xBPWxqVCocdBgybmHjr5V
# 2  spotify:episode:5xBPWxqVCocdBgybmHjr5V
# 3  spotify:episode:5xBPWxqVCocdBgybmHjr5V
# 4  spotify:episode:5xBPWxqVCocdBgybmHjr5V
#
#                                        top_responses  top_scores  total_time
# 0  So you got any anybody like to thank sponsor s...   91.726151        0.87
# 1                              I had some customers.   89.408089        0.87
# 2              Well, thanks a lot of guys like that.   89.261078        0.87
# 3          All right you guys to thanks a lot again.   89.106979        0.87
# 4                                            Thanks.   89.094635        0.87
#                               episode_uri  \
# 0  spotify:episode:0X663c1I6j1cehJvy10WMm
# 1  spotify:episode:0X663c1I6j1cehJvy10WMm
# 2  spotify:episode:0X663c1I6j1cehJvy10WMm
# 3  spotify:episode:0X663c1I6j1cehJvy10WMm
# 4  spotify:episode:0X663c1I6j1cehJvy10WMm
#
#                                        top_responses  top_scores  total_time
# 0  We are all in this together everything from bu...   89.035439        0.32
# 1  So I'm happy to say that I have enough faith i...   88.109879        0.32
# 2  Just went all over the faces of the people sit...   87.690369        0.32
# 3                   Thank you so much for listening.   87.602249        0.32
# 4  I want to talk about the impacts that are happ...   87.313004        0.32
#                               episode_uri  \
# 0  spotify:episode:61a1JjZO27lGCvCwBaCkpC
# 1  spotify:episode:61a1JjZO27lGCvCwBaCkpC
# 2  spotify:episode:61a1JjZO27lGCvCwBaCkpC
# 3  spotify:episode:61a1JjZO27lGCvCwBaCkpC
# 4  spotify:episode:61a1JjZO27lGCvCwBaCkpC
#
#                                        top_responses  top_scores  total_time
# 0                                         Thank you.   89.589943         0.7
# 1                                            Thanks.   89.094635         0.7
# 2  We're just so blessed and happy that you came ...   89.013054         0.7
# 3  We're so excited and you guys know where to fi...   88.213264         0.7
# 4  Behavior when presented with the same prompt t...   87.904770         0.7
#                               episode_uri  \
# 0  spotify:episode:0goWRy1gwB23rQVy8ci7Wa
# 1  spotify:episode:0goWRy1gwB23rQVy8ci7Wa
# 2  spotify:episode:0goWRy1gwB23rQVy8ci7Wa
# 3  spotify:episode:0goWRy1gwB23rQVy8ci7Wa
# 4  spotify:episode:0goWRy1gwB23rQVy8ci7Wa
#
#                                        top_responses  top_scores  total_time
# 0  Good job, but also we gave I put up a post on ...   87.776657         0.7
# 1  Questions to tackle, but before we start specu...   87.741821         0.7
# 2                     So thank you very much to you.   87.721283         0.7
# 3     It's a great I think message for anyone right?   87.452133         0.7
# 4  We have they've got they've given us officiall...   86.986946         0.7
#                               episode_uri  \
# 0  spotify:episode:0BSD8QYmd2mQ1V43uIrU4I
# 1  spotify:episode:0BSD8QYmd2mQ1V43uIrU4I
# 2  spotify:episode:0BSD8QYmd2mQ1V43uIrU4I
# 3  spotify:episode:0BSD8QYmd2mQ1V43uIrU4I
# 4  spotify:episode:0BSD8QYmd2mQ1V43uIrU4I
#
#                                        top_responses  top_scores  total_time
# 0  Ruminating on what mistakes the Christian demo...   86.351860        0.34
# 1  It was the red brigades each caller conveyed t...   86.301300        0.34
# 2  Accusation to make but that was it to everyone...   86.255318        0.34
# 3  Aldo was candid about the failings of the Chri...   86.128883        0.34
# 4  While these futile efforts continued a debate ...   86.128006        0.34
#                               episode_uri  \
# 0  spotify:episode:5xH3cdpkxnJhQjPV22sxKC
# 1  spotify:episode:5xH3cdpkxnJhQjPV22sxKC
# 2  spotify:episode:5xH3cdpkxnJhQjPV22sxKC
# 3  spotify:episode:5xH3cdpkxnJhQjPV22sxKC
# 4  spotify:episode:5xH3cdpkxnJhQjPV22sxKC
#
#                                        top_responses  top_scores  total_time
# 0  There are too many different motives only thre...   85.812935        0.18
# 1  Our next assassin had a more selfish reasoning...   85.683319        0.18
# 2  He said only four percent of victims receive d...   85.526329        0.18
# 3  It was a question fool and family echoed the i...   85.372192        0.18
# 4  Officially Booth wanted revenge on the man who...   85.049820        0.18
#                               episode_uri  \
# 0  spotify:episode:0YPvJfSEw0jacPB3IeT37d
# 1  spotify:episode:0YPvJfSEw0jacPB3IeT37d
# 2  spotify:episode:0YPvJfSEw0jacPB3IeT37d
# 3  spotify:episode:0YPvJfSEw0jacPB3IeT37d
# 4  spotify:episode:0YPvJfSEw0jacPB3IeT37d
#
#                                        top_responses  top_scores  total_time
# 0  So I highlighted a large section here, but I r...   87.531731        0.44
# 1  But if you're a person of color and have a lot...   87.215431        0.44
# 2  But first of all, we'll go through and do our ...   87.074615        0.44
# 3  You know, the one where they've got the main e...   86.967964        0.44
# 4  Thank you so much for joining us Anna you guys...   86.402550        0.44
#                               episode_uri  \
# 0  spotify:episode:1gnpv26FFvIxpnwVbbRXv1
# 1  spotify:episode:1gnpv26FFvIxpnwVbbRXv1
# 2  spotify:episode:1gnpv26FFvIxpnwVbbRXv1
# 3  spotify:episode:1gnpv26FFvIxpnwVbbRXv1
# 4  spotify:episode:1gnpv26FFvIxpnwVbbRXv1
#
#                                        top_responses  top_scores  total_time
# 0  If you have a message if you have some come co...   85.782341        0.09
# 1  I had my name balls did my practices I have re...   85.033485        0.09
# 2  Now my Skyrim everyone welcome back to my shoe...   84.972702        0.09
# 3  It's lot and I hope this possibilities availab...   84.891136        0.09
# 4  I want myself back sir, but accessible to you ...   84.821716        0.09
#                               episode_uri  \
# 0  spotify:episode:6rh4J52THn252yi7t11Yqf
# 1  spotify:episode:6rh4J52THn252yi7t11Yqf
# 2  spotify:episode:6rh4J52THn252yi7t11Yqf
# 3  spotify:episode:6rh4J52THn252yi7t11Yqf
# 4  spotify:episode:6rh4J52THn252yi7t11Yqf
#
#                                        top_responses  top_scores  total_time
# 0            I really apologize you and I thank you.   88.978973        0.47
# 1                                     I applaud you.   88.309372        0.47
# 2  Just please listen, he's helping me and it mak...   87.807602        0.47
# 3  I never dared me and I wish I did but I just n...   87.645622        0.47
# 4  Oh my God, I'm really a good friend and David ...   86.723396        0.47
#                               episode_uri  \
# 0  spotify:episode:3IfmcM2rcWb82601pkPvCh
# 1  spotify:episode:3IfmcM2rcWb82601pkPvCh
# 2  spotify:episode:3IfmcM2rcWb82601pkPvCh
# 3  spotify:episode:3IfmcM2rcWb82601pkPvCh
# 4  spotify:episode:3IfmcM2rcWb82601pkPvCh
#
#                                        top_responses  top_scores  total_time
# 0  Thank you listeners for supporting these incre...   89.696877        0.11
# 1  Today's episode is sponsored by glory and shin...   87.014542        0.11
# 2  Why didn't we see that showing up in love and ...   86.254257        0.11
# 3  She is Beloved the  Driver, yes beloved the ca...   86.108673        0.11
# 4  You can find her on Instagram at Krug The Thin...   86.108315        0.11
#                               episode_uri  \
# 0  spotify:episode:5LJ33LdXWhqOu1KNad6D5q
# 1  spotify:episode:5LJ33LdXWhqOu1KNad6D5q
# 2  spotify:episode:5LJ33LdXWhqOu1KNad6D5q
# 3  spotify:episode:5LJ33LdXWhqOu1KNad6D5q
# 4  spotify:episode:5LJ33LdXWhqOu1KNad6D5q
#
#                                        top_responses  top_scores  total_time
# 0  Thank you listeners for supporting these incre...   89.696877         0.1
# 1  Today's episode is sponsored by glory and shin...   87.014542         0.1
# 2  Today's episode is all  Also sponsored by pray...   85.987732         0.1
# 3  She is passionate about her faith and has cont...   85.194092         0.1
# 4            Please visit pray more Retreat dot-org.   84.700455         0.1
#                               episode_uri  \
# 0  spotify:episode:1AxFBio6NwwG0MAjdCK5gK
# 1  spotify:episode:1AxFBio6NwwG0MAjdCK5gK
# 2  spotify:episode:1AxFBio6NwwG0MAjdCK5gK
# 3  spotify:episode:1AxFBio6NwwG0MAjdCK5gK
# 4  spotify:episode:1AxFBio6NwwG0MAjdCK5gK
#
#                                        top_responses  top_scores  total_time
# 0                                         Thank you.   89.589943         0.2
# 1                                               Etc.   86.950890         0.2
# 2  I've got a question first well means please go...   85.642418         0.2
# 3  Even those trusted crew members can sometimes ...   85.614006         0.2
# 4  Our pilgrimage pod and Facebook at the pilgrim...   85.602974         0.2
#                               episode_uri  \
# 0  spotify:episode:3U33mRnDJcXywmBm1hahlL
# 1  spotify:episode:3U33mRnDJcXywmBm1hahlL
# 2  spotify:episode:3U33mRnDJcXywmBm1hahlL
# 3  spotify:episode:3U33mRnDJcXywmBm1hahlL
# 4  spotify:episode:3U33mRnDJcXywmBm1hahlL
#
#                                        top_responses  top_scores  total_time
# 0  Make sure to follow along with us know who you...   89.969749        0.89
# 1                                         Thank you.   89.589943        0.89
# 2                                         Thank you.   89.589943        0.89
# 3  We have some announcements and reminders is an...   88.014763        0.89
# 4  So Tina's like who's been Bianca that making m...   87.644440        0.89
#                               episode_uri  \
# 0  spotify:episode:57Nzb9H2VRZgHcNFChwbBG
# 1  spotify:episode:57Nzb9H2VRZgHcNFChwbBG
# 2  spotify:episode:57Nzb9H2VRZgHcNFChwbBG
# 3  spotify:episode:57Nzb9H2VRZgHcNFChwbBG
# 4  spotify:episode:57Nzb9H2VRZgHcNFChwbBG
#
#                                        top_responses  top_scores  total_time
# 0  Also, if you want to be if you want to sponsor...   89.189102        0.15
# 1                                         Thank God.   88.359428        0.15
# 2                   Thank you so much for listening.   87.602249        0.15
# 3  Hey, maybe one of those things of this hopeful...   86.950150        0.15
# 4  I'm on a  Mobile hairdressing page and I asked...   86.920303        0.15
#                               episode_uri  \
# 0  spotify:episode:6vRLNVEQ4xqtMxnms3RZh3
# 1  spotify:episode:6vRLNVEQ4xqtMxnms3RZh3
# 2  spotify:episode:6vRLNVEQ4xqtMxnms3RZh3
# 3  spotify:episode:6vRLNVEQ4xqtMxnms3RZh3
# 4  spotify:episode:6vRLNVEQ4xqtMxnms3RZh3
#
#                                        top_responses  top_scores  total_time
# 0  They love it and you know investors are drivin...   88.753769        0.34
# 1  We talked about earlier, but they also offer o...   88.405243        0.34
# 2      You know, I'm somebody who's been doing this.   87.956009        0.34
# 3  There's something called eBay Bucks A lot of p...   87.790627        0.34
# 4  If you want like links to those just DME and I...   87.660431        0.34
#                               episode_uri  \
# 0  spotify:episode:1tN044BhlPjjiluZ7Wo7UL
# 1  spotify:episode:1tN044BhlPjjiluZ7Wo7UL
# 2  spotify:episode:1tN044BhlPjjiluZ7Wo7UL
# 3  spotify:episode:1tN044BhlPjjiluZ7Wo7UL
# 4  spotify:episode:1tN044BhlPjjiluZ7Wo7UL
#
#                                        top_responses  top_scores  total_time
# 0     Thanks so much and we'll see you all tomorrow.   87.432022        0.16
# 1  So now that we've gone over the major points a...   85.319595        0.16
# 2  And most within one hour they did not comment ...   84.946251        0.16
# 3  Keep in mind that this podcast is designed to ...   84.841286        0.16
# 4  This is the ortho bullets podcast a daily audi...   84.583199        0.16
#                               episode_uri  \
# 0  spotify:episode:1fs86N6FLUKW2e5NdX1dF1
# 1  spotify:episode:1fs86N6FLUKW2e5NdX1dF1
# 2  spotify:episode:1fs86N6FLUKW2e5NdX1dF1
# 3  spotify:episode:1fs86N6FLUKW2e5NdX1dF1
# 4  spotify:episode:1fs86N6FLUKW2e5NdX1dF1
#
#                                        top_responses  top_scores  total_time
# 0  I would say like entirely  So I would like to ...   89.339706        0.44
# 1  Their appreciation support for the franchise a...   88.945366        0.44
# 2                    Thank you all for your support.   88.551247        0.44
# 3                          It would be very welcome.   87.483360        0.44
# 4  They're going to be paying attention to number...   87.419342        0.44
#                               episode_uri  \
# 0  spotify:episode:1A4cHtP3wIVQutpCgS7kd7
# 1  spotify:episode:1A4cHtP3wIVQutpCgS7kd7
# 2  spotify:episode:1A4cHtP3wIVQutpCgS7kd7
# 3  spotify:episode:1A4cHtP3wIVQutpCgS7kd7
# 4  spotify:episode:1A4cHtP3wIVQutpCgS7kd7
#
#                                        top_responses  top_scores  total_time
# 0             And that is it guys few announcements.   89.736458        0.86
# 1                          Thank you for joining us.   89.038361        0.86
# 2  Don't forget to like comment and subscribe to ...   87.686356        0.86
# 3  Like like you you hype up these people the ent...   87.495583        0.86
# 4                         Thanks for listening guys.   87.459137        0.86
#                               episode_uri  \
# 0  spotify:episode:1Mi90UjG91rm73qvHzcG0t
# 1  spotify:episode:1Mi90UjG91rm73qvHzcG0t
# 2  spotify:episode:1Mi90UjG91rm73qvHzcG0t
# 3  spotify:episode:1Mi90UjG91rm73qvHzcG0t
# 4  spotify:episode:1Mi90UjG91rm73qvHzcG0t
#
#                                        top_responses  top_scores  total_time
# 0                                       Hi everyone.   86.922188        0.02
# 1  In the near term Asian markets may be in for c...   83.844490        0.02
# 2  This has been a podcast from ocbc Bank follow ...   83.572586        0.02
# 3  I'm Selena Ling Chief Economist for CPC bang t...   83.389191        0.02
# 4  If you reference the G7 meeting of Finance Chi...   83.141045        0.02
#                               episode_uri  \
# 0  spotify:episode:3TuC8HZp9VdXtxYMQkJI0m
# 1  spotify:episode:3TuC8HZp9VdXtxYMQkJI0m
# 2  spotify:episode:3TuC8HZp9VdXtxYMQkJI0m
# 3  spotify:episode:3TuC8HZp9VdXtxYMQkJI0m
# 4  spotify:episode:3TuC8HZp9VdXtxYMQkJI0m
#
#                                        top_responses  top_scores  total_time
# 0                                         Thank you.   89.589943        0.11
# 1                I hope you do to thank you so much.   88.546982        0.11
# 2  He's with mr. D. Hello and welcome to Friday f...   86.276268        0.11
# 3          Thanks for having happy Friday everybody.   85.741425        0.11
# 4  I know they do have a parent or advisory warni...   85.498055        0.11
#                               episode_uri  \
# 0  spotify:episode:67v8V9SOXxivYQfAHSsc5f
# 1  spotify:episode:67v8V9SOXxivYQfAHSsc5f
# 2  spotify:episode:67v8V9SOXxivYQfAHSsc5f
# 3  spotify:episode:67v8V9SOXxivYQfAHSsc5f
# 4  spotify:episode:67v8V9SOXxivYQfAHSsc5f
#
#                                        top_responses  top_scores  total_time
# 0                    Thank you so much for chatting.   88.334587        0.18
# 1  Thank you so much for joining me on for the lo...   87.355186        0.18
# 2                          Thank you so much Rodman.   86.162308        0.18
# 3                         I'm so excited to be here.   85.876465        0.18
# 4  Do you have any tips for teachers I guess to p...   85.684448        0.18
#                               episode_uri  \
# 0  spotify:episode:3QE8qxHtJg3zMrq03R4GOj
# 1  spotify:episode:3QE8qxHtJg3zMrq03R4GOj
# 2  spotify:episode:3QE8qxHtJg3zMrq03R4GOj
# 3  spotify:episode:3QE8qxHtJg3zMrq03R4GOj
# 4  spotify:episode:3QE8qxHtJg3zMrq03R4GOj
#
#                                        top_responses  top_scores  total_time
# 0         We just want to say thanks to our sponsor.   95.078430        0.63
# 1  And today Spotify is one of our sponsors on Sp...   92.813988        0.63
# 2                                         Thank you.   89.589943        0.63
# 3                                         Thank you.   89.589943        0.63
# 4                                         Thank you.   89.589943        0.63
#                               episode_uri  \
# 0  spotify:episode:3Vr6AUCTQgVWoE137b4IdB
# 1  spotify:episode:3Vr6AUCTQgVWoE137b4IdB
# 2  spotify:episode:3Vr6AUCTQgVWoE137b4IdB
# 3  spotify:episode:3Vr6AUCTQgVWoE137b4IdB
# 4  spotify:episode:3Vr6AUCTQgVWoE137b4IdB
#
#                                        top_responses  top_scores  total_time
# 0  So that's and if I'm proud of it, but it's par...   87.354828        0.56
# 1                                            We are.   87.203232        0.56
# 2  But my guess is that people who work with you ...   87.027206        0.56
# 3  I think that you know, I just sort of help peo...   86.817032        0.56
# 4  for example  I can give you one example that c...   86.807785        0.56
#                               episode_uri  \
# 0  spotify:episode:4oQZAcd6xnxVA1e2GWaIFb
# 1  spotify:episode:4oQZAcd6xnxVA1e2GWaIFb
# 2  spotify:episode:4oQZAcd6xnxVA1e2GWaIFb
# 3  spotify:episode:4oQZAcd6xnxVA1e2GWaIFb
# 4  spotify:episode:4oQZAcd6xnxVA1e2GWaIFb
#
#                                        top_responses  top_scores  total_time
# 0                                         Thank you.   89.589943        0.23
# 1                                     But thank God.   88.522011        0.23
# 2             And thanks again for joining us today.   88.509727        0.23
# 3                              Thank you again, man.   88.089447        0.23
# 4  I've used other platforms, and I'm so happy I ...   87.564529        0.23
#                               episode_uri  \
# 0  spotify:episode:4sbSs1xtuf8dF3xtb7btUi
# 1  spotify:episode:4sbSs1xtuf8dF3xtb7btUi
# 2  spotify:episode:4sbSs1xtuf8dF3xtb7btUi
# 3  spotify:episode:4sbSs1xtuf8dF3xtb7btUi
# 4  spotify:episode:4sbSs1xtuf8dF3xtb7btUi
#
#                                        top_responses  top_scores  total_time
# 0  They will even help you find other companies t...   90.060837        0.46
# 1                                  We're your hosts.   89.264397        0.46
# 2  So they're waving and everything and because o...   87.569412        0.46
# 3  We want to take some time to introduce you to ...   87.446594        0.46
# 4  So again, thanks for listening and we'll see y...   86.970871        0.46
#                               episode_uri  \
# 0  spotify:episode:2RoLspr2PQTki51sfMhd20
# 1  spotify:episode:2RoLspr2PQTki51sfMhd20
# 2  spotify:episode:2RoLspr2PQTki51sfMhd20
# 3  spotify:episode:2RoLspr2PQTki51sfMhd20
# 4  spotify:episode:2RoLspr2PQTki51sfMhd20
#
#                                        top_responses  top_scores  total_time
# 0  We are grateful for you our listeners you allo...   90.327499        0.32
# 1  In other words Congressional staffers are  Ed ...   86.872383        0.32
# 2                              Thanks for listening.   86.267189        0.32
# 3  Is or his wife's election campaigns any favors...   86.216476        0.32
# 4  He'd already talked about wanting to work with...   85.902397        0.32

# %%
# indicator_episodes_df.to_excel('output/distilbert_dot_tasb_b256_msmarco_indicator_episodes.xlsx', index=False)

# %%
for df in of_interest:
    episode_uri = df.iloc[0,0].replace(":", "_")
    df.to_excel(f'output/distilbert_dot_tasb_{episode_uri}.xlsx', index=False)

# %% [markdown]
# # Examine results

# %%
import pandas as pd
path = 'output/Indicator_episode_results/recovery_distilbert_dot_tasb_true_score/'

episode_dfs = []
for num in range(3,33):
    indicator_episodes_df = pd.read_excel(f'{path}distil_dot_tasb_recovery_Sheet{num}.xlsx')
    episode_dfs.append(indicator_episodes_df)

# %%
episode_dfs[0].head()
# Out:
#                               episode_uri  \
# 0  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 1  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 2  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 3  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 4  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
#
#                                     human_identified  \
# 0   You don't even need a premium account Spotify...
# 1                                     Out on Spotify
# 2               You can follow your favorite podcast
# 3   And if you're a premium user you can download...
# 4   So if you haven't done so already be sure to ...
#
#               spotify:episode:5fG4VlWnWwzAt6mSs0H7lY  y_true  top_scores  \
# 0  Oh, yeah other Shooters we're super fortunate ...       0   89.197632
# 1  , I can't I can't but but like I'm just that's...       0   89.057426
# 2  , And I don't know there's a lot of people int...       0   88.724937
# 3  , It's always a great experience in like you'r...       0   88.405342
# 4  , It's just so funny shown up because there's ...       0   88.268860
#
#                                        top_responses
# 0  Oh, yeah other Shooters we're super fortunate ...
# 1  I can't I can't but but like I'm just that's w...
# 2  And I don't know there's a lot of people inter...
# 3  It's always a great experience in like you're ...
# 4  It's just so funny shown up because there's so...

# %%
import pandas as pd
path = 'output/recovery/distil_dot_tasb_recovery_'

scored_dfs = []

for scored_df in episode_dfs:

    # episode_uri = scored_df.iloc[0,0]
    # print(episode, episode_uri)

    # display(scored_df.head(2))
    scored_df['y_true'].fillna(0, inplace=True)
    
    scored_df.sort_values(by=['top_scores'], ascending=False, inplace=True)
    scored_dfs.append(scored_df)

# %%
from sklearn.metrics import ndcg_score
import numpy as np

# ordered greatest to least
ndcg_scores = []

for df in scored_dfs:
    episode_uri = df.iloc[0,0]
    true_relevance = np.asarray([df['y_true']])
    try:
        predicted_scores = np.asarray([df['top_scores']])
        ndcg = ndcg_score(true_relevance, predicted_scores)
    except ValueError as error:
        print(error)
        print("Episode URI: ", episode_uri)
        continue

    
    ndcg_scores.append(ndcg)
    print(episode_uri,"NDCG score: ", ndcg)

avg_ndcg_score = np.mean(ndcg_scores)
print('Average NDCG score: ', avg_ndcg_score, "for model: ", pre_trained_model_name)
# Out:
# spotify:episode:5fG4VlWnWwzAt6mSs0H7lY NDCG score:  0.0
# spotify:episode:7JG3lLnRoDdOxuqjf14ZkM NDCG score:  0.25
# spotify:episode:3kkhUQJ9DXYs6aSdDmPp2V NDCG score:  0.0
# spotify:episode:4fJ6Y6IpljKy8FT8DZHx1L NDCG score:  0.961999147059583
# spotify:episode:5xBPWxqVCocdBgybmHjr5V NDCG score:  1.0
# spotify:episode:0X663c1I6j1cehJvy10WMm NDCG score:  0.0
# spotify:episode:61a1JjZO27lGCvCwBaCkpC NDCG score:  0.0
# spotify:episode:0goWRy1gwB23rQVy8ci7Wa NDCG score:  0.40315091002613573
# spotify:episode:0BSD8QYmd2mQ1V43uIrU4I NDCG score:  0.0
# spotify:episode:5xH3cdpkxnJhQjPV22sxKC NDCG score:  0.21274605355336274
# spotify:episode:0YPvJfSEw0jacPB3IeT37d NDCG score:  0.0
# spotify:episode:1gnpv26FFvIxpnwVbbRXv1 NDCG score:  0.5387008702316818
# spotify:episode:6rh4J52THn252yi7t11Yqf NDCG score:  0.0
# spotify:episode:3IfmcM2rcWb82601pkPvCh NDCG score:  0.6013954160211185
# spotify:episode:5LJ33LdXWhqOu1KNad6D5q NDCG score:  0.7040965536719686
# spotify:episode:1AxFBio6NwwG0MAjdCK5gK NDCG score:  0.23137821315975948
# spotify:episode:3U33mRnDJcXywmBm1hahlL NDCG score:  0.24465054212771786
# spotify:episode:57Nzb9H2VRZgHcNFChwbBG NDCG score:  0.7381035537885072
# spotify:episode:6vRLNVEQ4xqtMxnms3RZh3 NDCG score:  0.0
# spotify:episode:1tN044BhlPjjiluZ7Wo7UL NDCG score:  0.4574945261898617
# spotify:episode:1fs86N6FLUKW2e5NdX1dF1 NDCG score:  0.5
# spotify:episode:1A4cHtP3wIVQutpCgS7kd7 NDCG score:  0.5
# spotify:episode:1Mi90UjG91rm73qvHzcG0t NDCG score:  0.5
# spotify:episode:3TuC8HZp9VdXtxYMQkJI0m NDCG score:  0.0
# spotify:episode:67v8V9SOXxivYQfAHSsc5f NDCG score:  0.20801459767650954
# spotify:episode:3QE8qxHtJg3zMrq03R4GOj NDCG score:  0.7976124081547706
# nan NDCG score:  0.0
# spotify:episode:4oQZAcd6xnxVA1e2GWaIFb NDCG score:  0.38685280723454163
# spotify:episode:4sbSs1xtuf8dF3xtb7btUi NDCG score:  0.6841742721852935
# spotify:episode:2RoLspr2PQTki51sfMhd20 NDCG score:  0.0
# Average NDCG score:  0.33067899570269377 for model:  sebastian-hofstaetter/distilbert-dot-tas_b-b256-msmarco

# %% [markdown]
# # Initial Test

# %% [markdown]
# ## Full Transcript - CSV

# %%
results = pd.read_csv("output/test_transcripts.csv")
test_1_transcript = results.loc[1, 'transcript']
results
# Out:
#    Unnamed: 0                             episode_uri  \
# 0           0  spotify:episode:5fG4VlWnWwzAt6mSs0H7lY
# 1           1  spotify:episode:2WQ1GcC6J0k7qsO8Vvf2be
# 2           2  spotify:episode:5hvOWPoB0j6HMrSVAMtJLV
#
#                                           transcript
# 0  What's up, guys? This episode of the podcast i...
# 1  What's up, everybody? Welcome to the in the do...
# 2  You are listening to Irish illustrate Insider....

# %%
# our relevant example
passage1_input = tokenizer(test_1_transcript[:], return_tensors="pt")

# the user query -> which should give us a better score for the first passage
query_input = tokenizer("who are the advertisers, sponsors, advertisement, or ads and/or businesses, people, teams thanked?",return_tensors="pt")
print("Passage 1 Tokenized:",tokenizer.convert_ids_to_tokens(passage1_input["input_ids"][0]))
print("Query Tokenized:",tokenizer.convert_ids_to_tokens(query_input["input_ids"][0]))
# note how we call the bert model independently between passages and query :)
# [0][:,0,:] pools (or selects) the CLS vector from the full output
passage1_encoded = bert_model(**passage1_input)[0][:,0,:].squeeze(0)
query_encoded    = bert_model(**query_input)[0][:,0,:].squeeze(0)

print("---")
print("Passage Encoded Shape:",passage1_encoded.shape)
print("Query Encoded Shape:",query_encoded.shape)
# Now that we have our encoded vectors, we can generate the score with a simple dot product!

# (This can be offloaded to a vector indexing library like Faiss)
score_for_p1 = query_encoded.dot(passage1_encoded)
print("Score passage 1 <-> query: ",float(score_for_p1))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (11768 > 512). Running this sequence through the model will result in indexing errors

# %% [markdown]
# ## By Sentence

# %%
episode_ = {
    "query": {
        "match_phrase": {
            "_id": 'spotify:episode:5fG4VlWnWwzAt6mSs0H7lY',
        }
    }
}

# Execute the Elasticsearch search query
# show_search_results = es.search(index="spotify_podcast_transcripts", body=show_body)
results = es.search(index="spotify_podcast_transcripts", body=episode_)

# Extract relevant information from the search results
hits = results["hits"]["hits"]

# %%
for sentence in hits[0]['_source']['sentence_tokens']:
    sentence_len = len(sentence)
    if sentence_len > 800:
        split_by = 2
        split = round(sentence_len // split_by,0)

        sentence_split = [sentence[i:i+split] for i in range(0, len(sentence), split)]
        print(len(sentence_split))
# Out:
# 2
# 2
# 3
# 3
# 2
# 3
# 3
# 2

# %%
query_input = tokenizer("who are the advertisers, sponsors, advertisement, or ads and/or businesses, people, teams thanked?",return_tensors="pt")
print("Query Tokenized:",tokenizer.convert_ids_to_tokens(query_input["input_ids"][0]))
query_encoded = bert_model(**query_input)[0][:,0,:].squeeze(0)

sentence_score = []

for sentence in hits[0]['_source']['sentence_tokens']:
    sentence_input = tokenizer(sentence, return_tensors="pt")
    tokenizer.convert_ids_to_tokens(sentence_input["input_ids"][0])
    passage1_encoded = bert_model(**sentence_input)[0][:,0,:].squeeze(0)
    score_for_p1 = query_encoded.dot(passage1_encoded)

    sentence_score.append((sentence, score_for_p1.item()))
# Out:
# Query Tokenized: ['[CLS]', 'who', 'are', 'the', 'ad', '##vert', '##iser', '##s', ',', 'sponsors', ',', 'advertisement', ',', 'or', 'ads', 'and', '/', 'or', 'businesses', ',', 'people', ',', 'teams', 'thanked', '?', '[SEP]']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 10
#       8 sentence_input = tokenizer(sentence, return_tensors="pt")
#       9 tokenizer.convert_ids_to_tokens(sentence_input["input_ids"][0])
# ---> 10 passage1_encoded = bert_model(**sentence_input)[0][:,0,:].squeeze(0)
#      11 score_for_p1 = query_encoded.dot(passage1_encoded)
#      13 sentence_score.append((sentence, score_for_p1.item()))
#
# File c:\Users\Olivia\anaconda3\envs\py38\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Olivia\anaconda3\envs\py38\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:480, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     477 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     479 if inputs_embeds is None:
# --> 480     inputs_embeds = self.embeddings(input_ids)  # (bs, seq_length, dim)
#     481 return self.transformer(
#     482     x=inputs_embeds,
#     483     attn_mask=attention_mask,
#    (...)
#     487     return_dict=return_dict,
#     488 )
#
# File c:\Users\Olivia\anaconda3\envs\py38\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Olivia\anaconda3\envs\py38\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:108, in Embeddings.forward(self, input_ids)
#     105 position_ids = position_ids.unsqueeze(0).expand_as(input_ids)  # (bs, max_seq_length)
#     107 word_embeddings = self.word_embeddings(input_ids)  # (bs, max_seq_length, dim)
# --> 108 position_embeddings = self.position_embeddings(position_ids)  # (bs, max_seq_length, dim)
#     110 embeddings = word_embeddings + position_embeddings  # (bs, max_seq_length, dim)
#     111 embeddings = self.LayerNorm(embeddings)  # (bs, max_seq_length, dim)
#
# File c:\Users\Olivia\anaconda3\envs\py38\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Olivia\anaconda3\envs\py38\lib\site-packages\torch\nn\modules\sparse.py:162, in Embedding.forward(self, input)
#     161 def forward(self, input: Tensor) -> Tensor:
# --> 162     return F.embedding(
#     163         input, self.weight, self.padding_idx, self.max_norm,
#     164         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File c:\Users\Olivia\anaconda3\envs\py38\lib\site-packages\torch\nn\functional.py:2210, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2204     # Note [embedding_renorm set_grad_enabled]
#    2205     # XXX: equivalent to
#    2206     # with torch.no_grad():
#    2207     #   torch.embedding_renorm_
#    2208     # remove once script supports set_grad_enabled
#    2209     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2210 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# IndexError: index out of range in self

# %%
sentence_score.sort(key=lambda tup: tup[1], reverse=True)
sentence_score[:25]
# Out:
# [('Thank you listeners for supporting these incredible Catholic businesses.',
#   89.6968765258789),
#  ("Today's episode is sponsored by glory and shine offering lotions soap bars lip balms beard care and much much more all of their products are natural wholesome and prayerfully designed and crafted to inspire the Catholic faithful during everyday acts of life and to promote prayer meditation on scripture and Marian devotion for ten percent off your entire order use promotional code Rua at checkout.",
#   87.01454162597656),
#  ("Why didn't we see that showing up in love and support would have been an act of worship true worship of our god of compassion and tenderness and mercy, I had missed my opportunity to love.",
#   86.25425720214844),
#  ('She is Beloved the  Driver, yes beloved the cashier checking me out at the grocery store.',
#   86.10867309570312),
#  ('You can find her on Instagram at Krug The Thinker listeners the ask that you sit with us pray with us.',
#   86.10831451416016),
#  ("Today's episode is all  Also sponsored by pray more novenas this Lent we can't recommend enough the pray more Retreat dot-org this online Retreat will help you meditate on the Lord's passion death and Resurrection.",
#   85.98773193359375),
#  ('Do you remember those trendy cliched bracelets of the 90s the neon ones and blazed with the letters?',
#   85.91099548339844),
#  ("We gathered in the conference room to make calls to her Russian insurance company and try to make heads or tails of her policy, which clearly wasn't set up.",
#   85.84156036376953),
#  ("I'm not saying that we should be looking for reasons to miss liturgies.",
#   85.76972198486328),
#  ('I loved God and my friends and I look forward to it every week.',
#   85.69242095947266),
#  ('I had missed the Liturgy, but I have been busy worshipping God finally, but finally I had done something right.',
#   85.52291107177734),
#  ('I was busy worshipping God I was doing things right.', 85.46709442138672),
#  ("I'm embarrassed to admit that it never occurred to me that God loved every single other human being just the exact same way without exception.",
#   85.38365936279297),
#  ('I long to be in my hushed and darkened parish and Berkeley venerating the cross, but I did not give it another thought as surely as Jesus was there in the Blessed Sacrament?',
#   85.21015930175781),
#  ("He'd been the one out there giving glory to God through his kindness his generosity his compassion.",
#   85.05216979980469),
#  ("I didn't know him personally, but I recognized his name another group of students immediately organized a benefit dinner for him on campus.",
#   85.02513885498047),
#  ('Give us Grace to help a to be helped by one another and in one another to comfort you Jesus Christ.',
#   84.93047332763672),
#  ('Please visit pray more Retreat dot-org.', 84.70045471191406),
#  ('When I took my eyes off myself long enough to actually look at the world around me to see the Beloved - of every person I crossed paths with it was as if a self-imposed blindfold had been removed from my face and that question does Jesus care about this became my constant companion does Jesus care about the person taking forever in front of me at the post office?',
#   84.64342498779297),
#  ('I was busy worshipping God.', 84.48969268798828),
#  ("Why didn't we cancel the worship service and attend that benefit dinner en masse?",
#   84.29299926757812),
#  ("It's been so long since that night in college when I miss my chance to be present for someone who is suffering as I was writing this story.",
#   84.27655792236328),
#  ('We met on Friday nights since every other night was already filled with acapella rehearsals rugby practices or good old-fashioned cramming for exams.',
#   84.19544219970703),
#  ('Does Jesus care about the conditions of the people who are making my clothes and overseas sweatshops does Jesus care about the people picking my food and terrible conditions for insulting pay does Jesus care about the men women and most terribly children treated atrociously for no reason other than the color of their skin.',
#   84.1444091796875),
#  ("I knew it was one of God's top priorities, but what did it have to do with me?",
#   84.13668060302734)]

# %% [markdown]
# ## Split and sentences

# %%
# num_sentences = hits[0]['_source']['num_sentences']

# for split_by in range(2,2):

#     if num_sentences % split_by == 0:
#         split = num_sentences / split_by
#         hits[0]['_source']['sentence_tokens'][:split]

num_sentences = hits[0]['_source']['num_sentences']

# create an interval to know where to split the sentences and create multiple intervals
intervals = np.array(list(range(0, num_sentences, 2)))

segments = [segment_[x:x + segment_length] for x in range(0, len(segment), segment_length)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 14
#      11 # create an interval to know where to split the sentences and create multiple intervals
#      12 intervals = np.array(list(range(0, num_sentences, 2)))
# ---> 14 segments = [segment_[x:x + segment_length] for x in range(0, len(segment), segment_length)]
#
# NameError: name 'segment' is not defined

# %%
# identify points to split the sentence_tokens, find last sentence in the split and then split the transcript

num_sentences = hits[0]['_source']['num_sentences']
split_by = 2

if num_sentences % split_by == 0:
    split = num_sentences // split_by

split_sentence = hits[0]['_source']['sentence_tokens'][split-1]  # Removed unnecessary slicing [split-1:split][0]
print("Split Sentence:", split_sentence)

# Find the index of split_sentence in the transcript
transcript = hits[0]['_source']['transcript']
split_index = transcript.find(split_sentence)

if split_index != -1:
    # Split the transcript based on the found index
    transcript_before_split = transcript[:split_index].strip()
    transcript_after_split = transcript[split_index + len(split_sentence):].strip()
else:
    print("Split sentence not found in the transcript.")


split_transcript = [transcript_before_split, transcript_after_split]

for num, transcript_part in enumerate(split_transcript):
    sentence_input = tokenizer(sentence, return_tensors="pt")
    tokenizer.convert_ids_to_tokens(sentence_input["input_ids"][0])
    passage1_encoded = bert_model(**sentence_input)[0][:,0,:].squeeze(0)
    score_for_p1 = query_encoded.dot(passage1_encoded)
    print("Score passage ", num, "<-> query: ",float(score_for_p1))
# Out:
# Split Sentence: Alright what I think we'll start to see is those two will start to play better as well because they would have been victims of the team on the wrong side of turning the tide.
# Score passage  0 <-> query:  83.94951629638672
# Score passage  1 <-> query:  83.94951629638672

# %%
# identify points to split the sentence_tokens, find last sentence in the split and then split the transcript

num_sentences = hits[0]['_source']['num_sentences']
split_by = 2

if num_sentences % split_by == 0:
    split = num_sentences // split_by

split_sentence = hits[0]['_source']['sentence_tokens'][split-1]  # Removed unnecessary slicing [split-1:split][0]
print("Split Sentence:", split_sentence)

# Find the index of split_sentence in the transcript
transcript = hits[0]['_source']['transcript']
split_index = transcript.find(split_sentence)

if split_index != -1:
    # Split the transcript based on the found index
    transcript_before_split = transcript[:split_index].strip()
    transcript_after_split = transcript[split_index + len(split_sentence):].strip()
else:
    print("Split sentence not found in the transcript.")

transcript_split = len(transcript_before_split)

transcript_split
# Out:
# Split Sentence: Alright what I think we'll start to see is those two will start to play better as well because they would have been victims of the team on the wrong side of turning the tide.
# 23898

# %%
test_1_transcript[:transcript_split]
# Out:
# "What's up, everybody? Welcome to the in the dome podcast podcast body are you doing hey, how you doing? I'm pretty good myself. All right. What do you want to talk about today? We got a breakdown. I know there's not much stock boat. We still haven't broken down the Columbus game, but cardiac / comeback kids come back. You know what that game room. Okay, I believe off the where we thought we were talking about a couple of episodes ago were talking about house like a toxic relationship and I was starting to get sucked back in. Yep.  And then I think you were to it's like when fully back on board is fully back with the Calgary Flames right now to start that podcast. I was like, I'm not I'm not falling for it. I've been hurt too many times by these guys, but by the end of that podcast we switched but I was still whatever. Yeah, I'm fine. I'm told I'm fully back. You're fully back. I'm proud. I'm not fully back. They've sucked me in that Columbus game. Got me back to being like, I think I'll die for this team. I think throughout all this up and down.  Really sobered me and to the fact that we are what we are we're not as good as we were last year. We're not as bad as we played form of the Season. We're somewhere in between. I think we're a playoff team were starting to turn a stuff around right now. Yeah. No, I believe I do believe I will say that.  It's weird because I feel like in the dog days of the season when you're in like December January and you're sucking ass. It's so hard to remain calm. But now that it's like there's there's like a light at the end of the tunnel and possibly playoff time. I feel like now it's like everything is good. Yeah for the most part. I don't know like we're the thing is it all signs point to that were trending up. Yeah, and we made it through listen some teams tragic suck ass here and Miss Laos.  Stork Lee some teams Trend in Surge late in the season, but they're coming out from the bottom of the standings and it's too late.  We were able to keep her head above water the whole season, even though we sucked ass been able to keep our head above water water over a racist coat incident our best defenseman or collapsing on the ice. I mean, what else happened something else happened? You may want to ask Johnny gaudreau has been terrible you want to ask you is that why best defenseman this season I said this season right? You just need your body best defenseman this season. I mean we've had Giordano has been hurt Monahan and drove not open them right there regular selves. It's like we've overcome so  Shit this year and we've come through it relatively. Okay, I'm fully back in love with this team. It helps that the Pacific Division is probably the weeks division of definitely helps definitely helps. Well, it's so funny because you texted me something to somebody to the other day. It's like Oilers fans right now or like the Oilers have 80 points there Stanley Cup contenders, but the Flames have 77 points morning make the playoffs make the playoffs and crazily enough if  if you check the standings as of right now, the Minnesota goddamn wild are in a playoff spot. Yeah, it's insane. Well, you saw it coming probably three weeks ago. They want a bit of a heater. They got themselves back in the race and they had game they've had games in hand. You saw it coming. I like the wild. I've always liked the Wild and I'd I said they make the laughs. I still I still think they didn't have a tough time of it. Like so only in by one point Vancouver's got a game in hand. So you think they will make it they they seem to be trending in surging right now.  I mean, they're still like 15 14 games left. The thing is is like I don't know man. They're the same position as Carrie where it's like it's their spot to lose. Yeah. We used to play a good hockey from here on in when a handful of games. I would say it would be it would be like Bizarro world if Edmonton Calgary Minnesota Vancouver made the playoffs in Nashville Winnipeg di ...

# %%
# our relevant example
passage1_input = tokenizer(test_1_transcript[:transcript_split], return_tensors="pt")
passage2_input = tokenizer(test_1_transcript[transcript_split:], return_tensors="pt")

# the user query -> which should give us a better score for the first passage
query_input = tokenizer("who are the advertisers, sponsors, advertisement, or ads and/or businesses, people, teams thanked?",return_tensors="pt")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (5793 > 512). Running this sequence through the model will result in indexing errors

# %%
# note how we call the bert model independently between passages and query :)
# [0][:,0,:] pools (or selects) the CLS vector from the full output
passage1_encoded = bert_model(**passage1_input)[0][:,0,:].squeeze(0)
passage2_encoded = bert_model(**passage2_input)[0][:,0,:].squeeze(0)
query_encoded    = bert_model(**query_input)[0][:,0,:].squeeze(0)

# (This can be offloaded to a vector indexing library like Faiss)
score_for_p1 = query_encoded.dot(passage1_encoded)
print("Score passage 1 <-> query: ",float(score_for_p1))

score_for_p2 = query_encoded.dot(passage2_encoded)
print("Score passage 1 <-> query: ",float(score_for_p2))

# %% [markdown]
# ## Use elasticsearch to get segments

# %%
episode_sentences = {
    "query": {
        "match": {
            "id_": 'spotify:episode:2WQ1GcC6J0k7qsO8Vvf2be',
        }
    }
}

# Execute the Elasticsearch search query
# show_search_results = es.search(index="spotify_podcast_transcripts", body=show_body)
results = es.search(index="transcripts_sentences", body=episode_sentences)

# Extract relevant information from the search results
hits = results["hits"]["hits"]

# %%
len(hits)
# Out:
# 0
